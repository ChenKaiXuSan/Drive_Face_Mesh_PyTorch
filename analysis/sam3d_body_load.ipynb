# %%
# load npz 
import numpy as np
flag = "left"
path = f"/workspace/data/sam3d_body_results/01/夜多い/{flag}/000000_sam3d_body.npz"
data = np.load(path, allow_pickle=True)

# %%
info = data['output'].item()
info.keys()
# Out:
# dict_keys(['bbox', 'focal_length', 'pred_keypoints_3d', 'pred_keypoints_2d', 'pred_vertices', 'pred_cam_t', 'pred_pose_raw', 'global_rot', 'body_pose_params', 'hand_pose_params', 'scale_params', 'shape_params', 'expr_params', 'mask', 'pred_joint_coords', 'pred_global_rots', 'mhr_model_params', 'lhand_bbox', 'rhand_bbox', 'frame', 'frame_idx'])

# %%
import matplotlib.pyplot as plt
plt.imshow(info['frame'])
